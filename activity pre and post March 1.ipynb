# %%
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
files = glob.glob('data-to-use/*.csv')

# %%
for f in files:
    df = pd.read_csv(f)
    df_2019=df[df.years == 2019]

# %%
df_2019
# Out:
#       Unnamed: 0  Unnamed: 0.1   ratings    action categories  dislikes  \
# 0          10224          5625       NaN  Searched         []       NaN
# 1           4598          4598  4.731159   Watched  ['Music']    2316.0
# 2           4597          4597  4.758218   Watched  ['Music']   21934.0
# 3           4596          4596  4.772699   Watched  ['Music']   19831.0
# 4           4595          4595  4.760785   Watched  ['Music']   24220.0
# ...          ...           ...       ...       ...        ...       ...
# 5976        6964          2365       NaN  Searched         []       NaN
# 5977        6963          2364       NaN   Visited         []       NaN
# 5978        6962          2363       NaN  Searched         []       NaN
# 5979        6961          2362       NaN  Searched         []       NaN
# 5980        6960          2361       NaN   Visited         []       NaN
#
#          likes  durations    view_cnts  years  months  days  hours  minutes  \
# ...

# %%
for f in files:
    df = pd.read_csv(f)
    df_jan_march=df[df.years == 2020]
    df_jan_march=df[df.months <= 3]

# %%
df_jan_march
# Out:
#        Unnamed: 0  Unnamed: 0.1  ratings    action  \
# 5981         6959          2360      NaN  Searched
# 5982         6958          2359      NaN  Searched
# 5983         6957          2358      NaN   Visited
# 5984         6956          2357      NaN  Searched
# 5985         6955          2356      NaN  Searched
# ...           ...           ...      ...       ...
# 10220        4603             4      NaN  Searched
# 10221        4602             3      NaN   Visited
# 10222        4600             1      NaN   Visited
# 10223        4601             2      NaN  Searched
# 10224        4599             0      NaN  Searched
#
#                                               categories  dislikes  likes  \
# 5981                                                  []       NaN    NaN
# 5982                                                  []       NaN    NaN
# 5983                                                  []       NaN    NaN
# ...

# %%
for f in files:
    df = pd.read_csv(f)
    df_march=df[df.years == 2020]
    df_march=df[df.months == 3]

# %%
df_march
# Out:
#        Unnamed: 0  Unnamed: 0.1  ratings    action  \
# 9297         5036           437      NaN  Searched
# 9298         5035           436      NaN   Visited
# 9299         5037           438      NaN  Searched
# 9300         5033           434      NaN   Visited
# 9301         5034           435      NaN  Searched
# ...           ...           ...      ...       ...
# 10220        4603             4      NaN  Searched
# 10221        4602             3      NaN   Visited
# 10222        4600             1      NaN   Visited
# 10223        4601             2      NaN  Searched
# 10224        4599             0      NaN  Searched
#
#                                               categories  dislikes  likes  \
# 9297                                                  []       NaN    NaN
# 9298   [['/Food & Drink/Beverages/Alcoholic Beverages...       NaN    NaN
# 9299                                                  []       NaN    NaN
# ...

# %%
df_2019.weekdays.value_counts().reset_index(name='queries per weekday').plot(y='queries per weekday')

# %%
df_jan_march.weekdays.value_counts().reset_index(name='queries per weekday').plot(y='queries per weekday')

# %%
df_march.weekdays.value_counts().reset_index(name='queries per weekday').plot(y='queries per weekday')

# %%
df_2019.days.value_counts().reset_index(name='queries per day').plot(y='queries per day')

# %%
for f in files:
    df = pd.read_csv(f)
    df_jan=df[df.years == 2020]
    df_jan=df[df.months == 1]

df_jan
# Out:
#       Unnamed: 0  Unnamed: 0.1  ratings    action  \
# 5981        6959          2360      NaN  Searched
# 5982        6958          2359      NaN  Searched
# 5983        6957          2358      NaN   Visited
# 5984        6956          2357      NaN  Searched
# 5985        6955          2356      NaN  Searched
# ...          ...           ...      ...       ...
# 7530        6031          1432      NaN   Visited
# 7531        6030          1431      NaN  Searched
# 7532        6029          1430      NaN  Searched
# 7533        6028          1429      NaN   Visited
# 7534        6027          1428      NaN       NaN
#
#                                              categories  dislikes  likes  \
# 5981                                                 []       NaN    NaN
# 5982                                                 []       NaN    NaN
# 5983                                                 []       NaN    NaN
# ...

# %%
df_jan.days.value_counts().reset_index(name='queries per day').plot(y='queries per day')

# %%
for f in files:
    df = pd.read_csv(f)
    df_feb=df[df.years == 2020]
    df_feb=df[df.months == 2]

# %%
df_feb.days.value_counts().reset_index(name='queries per day').plot(y='queries per day')

# %%
df_march.days.value_counts().reset_index(name='queries per day').plot(y='queries per day')

# %%
df_2019.hours.value_counts().reset_index(name='queries per hour').plot(y='queries per hour')

# %%
df_jan.hours.value_counts().reset_index(name='queries per hour').plot(y='queries per hour')

# %%
df_feb.hours.value_counts().reset_index(name='queries per hour').plot(y='queries per hour')

# %%
df_march.hours.value_counts().reset_index(name='queries per hour').plot(y='queries per hour')

# %%
df_jan_march.hours.value_counts().reset_index(name='queries per hour').plot(y='queries per hour')

# %%
df_2019.dropna(subset=['durations'])
df_jan.dropna(subset=['durations'])
df_feb.dropna(subset=['durations'])
df_march.dropna(subset=['durations'])
df_jan_march.dropna(subset=['durations'])
# Out:
#       Unnamed: 0  Unnamed: 0.1   ratings   action           categories  \
# 6012        1882          1882  4.245283  Watched   ['People & Blogs']
# 6013        1881          1881  4.151515  Watched  ['News & Politics']
# 6014        1880          1880  4.620053  Watched           ['Comedy']
# 6016        1878          1878  4.301075  Watched    ['Entertainment']
# 6047        1877          1877  4.786138  Watched           ['Comedy']
# ...          ...           ...       ...      ...                  ...
# 9276         494           494  4.856497  Watched            ['Music']
# 9277         493           493  4.758218  Watched            ['Music']
# 9278         492           492  4.771863  Watched            ['Music']
# 9279         491           491  4.615052  Watched            ['Music']
# 9282         489           489  4.914754  Watched    ['Entertainment']
#
#       dislikes     likes  durations   view_cnts  years  months  days  hours  \
# ...

# %%
df_2019.groupby('days').durations.mean().reset_index(name='duration per day').plot(y='duration per day')

# %%
df_jan.groupby('days').durations.mean().reset_index(name='duration per day').plot(y='duration per day')

# %%
df_feb.groupby('days').durations.mean().reset_index(name='duration per day').plot(y='duration per day')

# %%
df_march.groupby('days').durations.mean().reset_index(name='duration per day').plot(y='duration per day')

# %%
df_2019.groupby('hours').durations.mean().reset_index(name='duration per hour').plot(y='duration per hour')

# %%
df_jan.groupby('hours').durations.mean().reset_index(name='duration per hour').plot(y='duration per hour')

# %%
df_feb.groupby('hours').durations.mean().reset_index(name='duration per hour').plot(y='duration per hour')

# %%
df_march.groupby('hours').durations.mean().reset_index(name='duration per hour').plot(y='duration per hour')

# %%
df_jan_march.groupby('hours').durations.mean().reset_index(name='duration per hour').plot(y='duration per hour')

# %%
df_2019.groupby('weekdays').durations.mean().reset_index(name='duration per weekday').plot(y='duration per weekday')

# %%
df_jan.groupby('weekdays').durations.sum().reset_index(name='duration per weekday').plot(y='duration per weekday')

# %%
df_feb.groupby('weekdays').durations.mean().reset_index(name='duration per weekday').plot(y='duration per weekday')

# %%
df_march.groupby('weekdays').durations.mean().reset_index(name='duration per weekday').plot(y='duration per weekday')

# %%
df_jan_march.groupby('weekdays').durations.mean().reset_index(name='duration per weekday').plot(y='duration per weekday')

# %%
df_2019.dropna(subset=['categories'])
df_jan.dropna(subset=['categories'])
df_feb.dropna(subset=['categories'])
df_march.dropna(subset=['categories'])
df_jan_march.dropna(subset=['categories'])
# Out:
#       Unnamed: 0  Unnamed: 0.1  ratings    action  \
# 5981        6959          2360      NaN  Searched
# 5982        6958          2359      NaN  Searched
# 5983        6957          2358      NaN   Visited
# 5984        6956          2357      NaN  Searched
# 5985        6955          2356      NaN  Searched
# ...          ...           ...      ...       ...
# 9292        5042           443      NaN  Searched
# 9293        5041           442      NaN  Searched
# 9294        5039           440      NaN   Visited
# 9295        5040           441      NaN   Visited
# 9296        5038           439      NaN   Visited
#
#                                              categories  dislikes  likes  \
# 5981                                                 []       NaN    NaN
# 5982                                                 []       NaN    NaN
# 5983                                                 []       NaN    NaN
# ...

# %%
df_2019_2 = df_2019.categories.value_counts().reset_index(name='category_count')
df_2019_2
# Out:
#                                                   index  category_count
# 0                                             ['Music']            1621
# 1                                                    []            1036
# 2                                     ['Entertainment']             318
# 3                                    ['People & Blogs']             226
# 4                                            ['Sports']              76
# ...                                                 ...             ...
# 1555   [['/Business & Industrial', 0.6200000047683716]]               1
# 1556  [['/Hobbies & Leisure/Water Activities/Boating...               1
# 1557        [['/Shopping/Apparel', 0.8899999856948853]]               1
# 1558  [['/Sports/Team Sports/Soccer', 0.949999988079...               1
# 1559  [['/Health/Medical Facilities & Services/Hospi...               1
#
# [1560 rows x 2 columns]

# %%
import ast
def get_cat_name(string):
    if string:
        if type(string) != float:
            content = ast.literal_eval(string)
            if type(content) == list:
                if len(content) != 0:
                    cat_name = content[0]
                    if type(content[0]) == list:
                        cat_name = content[0][0].split('/')[1] 
                    return cat_name

# %%
df_jan_2 = df_jan.categories.value_counts().reset_index(name='category_count')
df_jan_2
# Out:
#                                                  index  category_count
# 0                                                   []             601
# 1                                            ['Music']             294
# 2                                    ['Entertainment']              90
# 3                                   ['People & Blogs']              71
# 4                                           ['Sports']              19
# ..                                                 ...             ...
# 270  [['/Jobs & Education/Education/Colleges & Univ...               1
# 271  [['/News/Sports News', 0.8500000238418579], ['...               1
# 272  [['/Arts & Entertainment/Movies', 0.8000000119...               1
# 273  [['/Jobs & Education/Education/Primary & Secon...               1
# 274  [['/Business & Industrial', 0.6000000238418579...               1
#
# [275 rows x 2 columns]

# %%
df_feb_2 = df_feb.categories.value_counts().reset_index(name='category_count')
df_feb_2
# Out:
#                                                  index  category_count
# 0                                                   []             528
# 1                                            ['Music']             324
# 2                                    ['Entertainment']             117
# 3                                   ['People & Blogs']              84
# 4                                 ['Film & Animation']              20
# ..                                                 ...             ...
# 392  [['/Reference/Language Resources', 0.939999997...               1
# 393  [['/Business & Industrial/Business Services', ...               1
# 394  [['/Computers & Electronics', 0.56999999284744...               1
# 395                   [['/Games', 0.6000000238418579]]               1
# 396  [['/Arts & Entertainment/Online Media/Online I...               1
#
# [397 rows x 2 columns]

# %%
df_march_2 = df_march.categories.value_counts().reset_index(name='category_count')
df_march_2
# Out:
#                                                 index  category_count
# 0                                                  []             378
# 1                                           ['Music']             193
# 2                                  ['People & Blogs']              87
# 3                                   ['Entertainment']              65
# 4                                          ['Comedy']              19
# ..                                                ...             ...
# 64    [['/Arts & Entertainment', 0.5400000214576721]]               1
# 65  [['/People & Society/Social Sciences', 0.92000...               1
# 66  [['/Food & Drink/Beverages/Alcoholic Beverages...               1
# 67  [['/Law & Government/Public Safety/Law Enforce...               1
# 68  [['/Sports/International Sports Competitions/O...               1
#
# [69 rows x 2 columns]

# %%
df_jan_march_2 = df_jan_march.categories.value_counts().reset_index(name='category_count')
df_jan_march_2
# Out:
#                                                  index  category_count
# 0                                                   []            1129
# 1                                            ['Music']             618
# 2                                    ['Entertainment']             207
# 3                                   ['People & Blogs']             155
# 4                                           ['Sports']              37
# ..                                                 ...             ...
# 614  [['/Sports/Individual Sports/Golf', 0.98000001...               1
# 615           [['/News/Politics', 0.9800000190734863]]               1
# 616  [['/Jobs & Education/Education/Standardized & ...               1
# 617  [['/Arts & Entertainment/Music & Audio', 0.910...               1
# 618  [['/Arts & Entertainment/Online Media/Online I...               1
#
# [619 rows x 2 columns]

# %%
df_2019.dropna(subset=['query'])
df_jan.dropna(subset=['query'])
df_feb.dropna(subset=['query'])
df_march.dropna(subset=['query'])
df_jan_march.dropna(subset=['query'])
# Out:
#       Unnamed: 0  Unnamed: 0.1  ratings    action  \
# 5981        6959          2360      NaN  Searched
# 5982        6958          2359      NaN  Searched
# 5983        6957          2358      NaN   Visited
# 5984        6956          2357      NaN  Searched
# 5985        6955          2356      NaN  Searched
# ...          ...           ...      ...       ...
# 9292        5042           443      NaN  Searched
# 9293        5041           442      NaN  Searched
# 9294        5039           440      NaN   Visited
# 9295        5040           441      NaN   Visited
# 9296        5038           439      NaN   Visited
#
#                                              categories  dislikes  likes  \
# 5981                                                 []       NaN    NaN
# 5982                                                 []       NaN    NaN
# 5983                                                 []       NaN    NaN
# ...

# %%
df_2019_3 = df_2019['query'].value_counts().reset_index(name='query_count')
df_2019_3
# Out:
#                                                   index  query_count
# 0                     https://www.rochester.edu/people/           31
# 1                                                  hrms           26
# 2                                        hrms rochester           24
# 3                     Photo Roster Login | Photo Roster           18
# 4                                    simon photo roster           16
# ...                                                 ...          ...
# 2770  News: Breaking News, National news, Latest Bol...            1
# 2771  Options vs. Futures: What's the Difference? - ...            1
# 2772  https://m.timesofindia.com/india/haryana-assem...            1
# 2773            https://en.m.wikipedia.org/wiki/Sikhism            1
# 2774                             art basel banana eaten            1
#
# [2775 rows x 2 columns]

# %%
df_jan_3 = df_jan['query'].value_counts().reset_index(name='query_count')
df_jan_3
# Out:
#                                                  index  query_count
# 0                                      google calendar           10
# 1                                    Calendar - Google            9
# 2    Shuttles | Department of Transportation and Pa...            8
# 3                                  eng vs south africa            7
# 4                                     rochester squash            5
# ..                                                 ...          ...
# 838                                    7 degree c to f            1
# 839                                           linkedin            1
# 840                                      icc president            1
# 841                     frederick douglass dining hall            1
# 842                                        cvs careers            1
#
# [843 rows x 2 columns]

# %%
df_feb_3 = df_feb['query'].value_counts().reset_index(name='query_count')
df_feb_3
# Out:
#                                                  index  query_count
# 0    Shuttles | Department of Transportation and Pa...           12
# 1    www.rochester.edu/parking/wp-content/uploads/2...           10
# 2                    blue line university of rochester           10
# 3                                     rochester squash            7
# 4                       HRMS - University of Rochester            6
# ..                                                 ...          ...
# 872                 how to calculate clv of a customer            1
# 873  Distance Calculator - How far is it from Roche...            1
# 874                                              m/g/1            1
# 875                         laureus sports awards 2020            1
# 876                                          gac hours            1
#
# [877 rows x 2 columns]

# %%
df_jan_march_3 = df_jan_march['query'].value_counts().reset_index(name='query_count')
df_jan_march_3
# Out:
#                                                   index  query_count
# 0     Shuttles | Department of Transportation and Pa...           20
# 1                     blue line university of rochester           14
# 2                                       google calendar           13
# 3                                     Calendar - Google           12
# 4     www.rochester.edu/parking/wp-content/uploads/2...           12
# ...                                                 ...          ...
# 1685                                   hercules triumph            1
# 1686  News: Breaking News, National news, Latest Bol...            1
# 1687  Global Powers of Luxury Goods 2019 Bridging th...            1
# 1688                 Ravindra Kishore Sinha - Wikipedia            1
# 1689                                        cvs careers            1
#
# [1690 rows x 2 columns]

# %%
df_march_3 = df_march['query'].value_counts().reset_index(name='query_count')
df_march_3
# Out:
#                                             index  query_count
# 0                                            hrms            4
# 1                              time in california            4
# 2                  HRMS - University of Rochester            4
# 3                                   gac closed ur            3
# 4    Current Outbreak of Coronavirus Disease 2019            3
# ..                                            ...          ...
# 410                             mad max fury road            1
# 411         time difference between nyc and dubai            1
# 412                             patty windmueller            1
# 413      https://en.m.wikipedia.org/wiki/Hinduism            1
# 414            MBA Leadership Development Program            1
#
# [415 rows x 2 columns]

# %%
df_2019.groupby(['source','days']).sum()
# Out:
#               Unnamed: 0  Unnamed: 0.1     ratings   dislikes       likes  \
# source  days
# search  1         671938        327013    0.000000        0.0         0.0
#         2         857239        415735    0.000000        0.0         0.0
#         3        1103449        514777    0.000000        0.0         0.0
#         4         673990        315268    0.000000        0.0         0.0
#         5         857866        416362    0.000000        0.0         0.0
# ...                  ...           ...         ...        ...         ...
# youtube 27        362806        362806  351.909954  2113430.0  32747077.0
#         28        430876        430876  524.867010  3531024.0  59152776.0
#         29        242017        242017  354.430330  1587906.0  24350197.0
#         30        196558        196558  266.346510  2416856.0  40488820.0
#         31        135022        135022  165.580544  1116867.0  19182359.0
#
# ...

# %%
search_counts_2019 = []
youtube_counts_2019 = []
for f in files:
    df = pd.read_csv(f)
    df_2019 = df[df.years == 2019]
    v = df_2019.source.value_counts()
    if 'search' in v:
        search_counts_2019.append(v.search)

    if 'youtube' in v:
        youtube_counts_2019.append(v.youtube)

youtube_counts_2019 = np.array(youtube_counts)/sum(youtube_counts)    
search_counts_2019 = np.array(search_counts)/sum(search_counts)    

# df_search = pd.DataFrame(search_counts_2019, columns = ['search_counts'])
# df_YT = pd.DataFrame(youtube_counts_2019, columns = ['YT_counts'])

df_grouped = df_2019.groupby(['source', 'months']).count().reset_index()
df_grouped[['months', 'action', 'source']]
watched = df_grouped[df_grouped['source'] == 'youtube']
searched = df_grouped[df_grouped['source'] == 'search']

plot2 = plt.plot(searched['months'], searched['action'])
plot1 = plt.plot(watched['months'], watched['action'])
plt.xlabel('month')
plt.ylabel('media count')
# Out:
# Text(0, 0.5, 'media count')

# %%
search_counts_jan = []
youtube_counts_jan = []
for f in files:
    df = pd.read_csv(f)
    df_jan_march=df[df.years == 2020]
    df_jan_march=df[df.months < 4]
    v = df_jan.source.value_counts()
    if 'search' in v:
        search_counts_jan.append(v.search)

    if 'youtube' in v:
        youtube_counts_jan.append(v.youtube)

youtube_counts_jan = np.array(youtube_counts)/sum(youtube_counts)    
search_counts_jan = np.array(search_counts)/sum(search_counts)    

df_grouped = df_jan_march.groupby(['source', 'months']).count().reset_index()
df_grouped[['months', 'action', 'source']]
watched = df_grouped[df_grouped['source'] == 'youtube']
searched = df_grouped[df_grouped['source'] == 'search']

plot2 = plt.plot(searched['months'], searched['action'])
plot1 = plt.plot(watched['months'], watched['action'])
plt.xlabel('month')
plt.ylabel('media count')
# Out:
# Text(0, 0.5, 'media count')

# %%
df_2019.dropna(subset=['query'])
df_jan.dropna(subset=['query'])
df_feb.dropna(subset=['query'])
df_march.dropna(subset=['query'])
df_jan_march.dropna(subset=['query'])

import ast
def get_cat_name(string):
    if string:
        if type(string) != float:
            content = ast.literal_eval(string)
            if type(content) == list:
                if len(content) != 0:
                    cat_name = content[0]
                    if type(content[0]) == list:
                        cat_name = content[0][0].split('/')[1] 
                    return cat_name

search_list_2019 = df_2019['query'].to_list()
search_list_jan = df_jan['query'].to_list()
search_list_feb = df_feb['query'].to_list()
search_list_march = df_march['query'].to_list()
search_list_jan_march = df_jan_march['query'].to_list()

# for e in search_list_2019:
#     get_cat_name(e)
    
    
# for e in search_list_jan:
#     get_cat_name(e)

    
# for e in search_list_feb:
#     get_cat_name(e)
    
    
# for e in search_list_march:
#     get_cat_name(e)
    
    
# for e in search_list_jan_march:
#     get_cat_name(e)

# %%
cat_list_2019 = df_2019['categories'].to_list()
cat_list_jan = df_jan['categories'].to_list()
cat_list_feb = df_feb['categories'].to_list()
cat_list_march = df_march['categories'].to_list()
cat_list_jan_march = df_jan_march['categories'].to_list()

cat_list_2019_fix = []
cat_list_jan_fix = []
cat_list_feb_fix = []
cat_list_march_fix = []
cat_list_jan_march_fix = []

for e in cat_list_2019:
    cat_list_2019_fix.append(get_cat_name(e))
    
for e in cat_list_jan:
    cat_list_jan_fix.append(get_cat_name(e))
    
for e in cat_list_feb:
    cat_list_feb_fix.append(get_cat_name(e))
    
for e in cat_list_march:
    cat_list_march_fix.append(get_cat_name(e))
    
for e in cat_list_jan_march:
    cat_list_jan_march_fix.append(get_cat_name(e))

df_2019_cat = pd.DataFrame(cat_list_2019_fix, columns = ['category'])
df_jan_cat = pd.DataFrame(cat_list_jan_fix, columns = ['category'])
df_feb_cat = pd.DataFrame(cat_list_feb_fix, columns = ['category'])
df_march_cat = pd.DataFrame(cat_list_march_fix, columns = ['category'])
df_jan_march_cat = pd.DataFrame(cat_list_jan_march_fix, columns = ['category'])

df_2019_cat['category'].value_counts().reset_index(name='cat_count').plot.bar(x='index', y='cat_count')

# %%
df_jan_cat['category'].value_counts().reset_index(name='cat_count')
# Out:
# Empty DataFrame
# Columns: [index, cat_count]
# Index: []

# %%
df_feb_cat['category'].value_counts().reset_index(name='cat_count').plot.bar(x='index', y='cat_count')

# %%
df_march_cat['category'].value_counts().reset_index(name='cat_count').plot.bar(x='index', y='cat_count')

# %%
df_jan_march_cat['category'].value_counts().reset_index(name='cat_count').plot.bar(x='index', y='cat_count')

# %%
from nltk.stem import PorterStemmer 
from nltk.tokenize import word_tokenize 

df_2019.dropna(subset=['query'])
df_jan.dropna(subset=['query'])
df_feb.dropna(subset=['query'])
df_march.dropna(subset=['query'])
df_jan_march.dropna(subset=['query'])

file_list = open("words_list.txt", "r")
list_of_words = []
for line in file_list:
    stripped_line = line.strip()
    line_list = stripped_line.split()
    list_of_words.append(line_list)

file_list.close()
# print(list_of_words)

search_list_2019 = df_2019['query'].to_list()
search_list_jan = df_jan['query'].to_list()
search_list_feb = df_feb['query'].to_list()
search_list_march = df_march['query'].to_list()
search_list_jan_march = df_jan_march['query'].to_list()

keyword_stemmed_list = []
for l in list_of_words:
    for w in l:
        keyword_stemmed_list.append(ps.stem(w))
        
keyword_stemmed_list = list(dict.fromkeys(keyword_stemmed_list))
keyword_stemmed_list.remove('a')
keyword_stemmed_list.remove('in')
keyword_stemmed_list.remove('or')
keyword_stemmed_list.remove('it')
keyword_stemmed_list.remove('of')
keyword_stemmed_list.remove('to')
keyword_stemmed_list.remove('is')

cleaned_search_list_2019=[x for x in search_list_2019 if str(x) != 'nan']
common = []
for search_term in cleaned_search_list_2019:
    for keyword in keyword_stemmed_list:
        if search_term.find(keyword) > -1:
            common.append(keyword)
            

df_keywords = pd.DataFrame(common, columns=['keywords'])
df_keywords['keywords'].value_counts().reset_index(name='count').plot.bar(x='index', y='count')

# %%
file_list = open("words_list.txt", "r")
list_of_words = []
for line in file_list:
    stripped_line = line.strip()
    line_list = stripped_line.split()
    list_of_words.append(line_list)

file_list.close()
# print(list_of_words)

search_list_2019 = df_2019['query'].to_list()
search_list_jan = df_jan['query'].to_list()
search_list_feb = df_feb['query'].to_list()
search_list_march = df_march['query'].to_list()
search_list_jan_march = df_jan_march['query'].to_list()

keyword_stemmed_list = []
for l in list_of_words:
    for w in l:
        keyword_stemmed_list.append(ps.stem(w))
        
keyword_stemmed_list = list(dict.fromkeys(keyword_stemmed_list))
keyword_stemmed_list.remove('a')
keyword_stemmed_list.remove('in')
keyword_stemmed_list.remove('or')
keyword_stemmed_list.remove('it')
keyword_stemmed_list.remove('of')
keyword_stemmed_list.remove('to')
keyword_stemmed_list.remove('is')

cleaned_search_list_jan_march=[x for x in search_list_jan_march if str(x) != 'nan']
common_jan_march = []
for search_term in cleaned_search_list_jan_march:
    for keyword in keyword_stemmed_list:
        if search_term.find(keyword) > -1:
            common_jan_march.append(keyword)
            

df_keywords = pd.DataFrame(common_jan_march, columns=['keywords'])
df_keywords['keywords'].value_counts().reset_index(name='count').plot.bar(x='index', y='count')


cleaned_search_list_feb=[x for x in search_list_feb if str(x) != 'nan']
common_feb = []
for search_term in cleaned_search_list_feb:
    for keyword in keyword_stemmed_list:
        if search_term.find(keyword) > -1:
            common_feb.append(keyword)
            

df_keywords = pd.DataFrame(common_feb, columns=['keywords'])
df_keywords['keywords'].value_counts().reset_index(name='count').plot.bar(x='index', y='count')


cleaned_search_list_march=[x for x in search_list_march if str(x) != 'nan']
common_march = []
for search_term in cleaned_search_list_march:
    for keyword in keyword_stemmed_list:
        if search_term.find(keyword) > -1:
            common_march.append(keyword)
            

df_keywords = pd.DataFrame(common_march, columns=['keywords'])
df_keywords['keywords'].value_counts().reset_index(name='count').plot.bar(x='index', y='count')
