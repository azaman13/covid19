# %%
conda install pandas
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/miriamblumenthal/opt/anaconda3/envs/covidProject
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-1.0                   |              mkl           6 KB
#     mkl_random-1.1.1           |   py37h959d312_0         284 KB
#     numpy-1.18.1               |   py37h7241aed_0           5 KB
#     numpy-base-1.18.1          |   py37h3304bdc_1         3.9 MB
#     pandas-1.0.3               |   py37h6c726b0_0         7.7 MB
#     pytz-2020.1                |             py_0         184 KB
#     ------------------------------------------------------------
#                                            Total:        12.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   blas               pkgs/main/osx-64::blas-1.0-mkl
# ...

# %%
import pandas as pd
import nltk
from nltk.corpus import wordnet
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize, sent_tokenize 
stop_words = set(stopwords.words('english'))

# %%
pwd
# Out:
# '/Users/miriamblumenthal/Desktop/Desktop/GoogleTake2'

# %%
df = pd.read_csv(r"/Users/miriamblumenthal/Desktop/Desktop/GoogleTake2/data-to-use/1_17.csv")

# %%
df_jan = df[(df.months == 1) & (df.years == 2020)]

# %%
df_jan
# Out:
#      Unnamed: 0  Unnamed: 0.1  ratings    action  \
# 762         284           269      NaN  Searched
# 763         283           268      NaN  Searched
# 764         281           266      NaN   Visited
# 765         282           267      NaN  Searched
# 766         280           265      NaN  Searched
# ..          ...           ...      ...       ...
# 912         134           119      NaN  Searched
# 913         133           118      NaN  Searched
# 914         132           117      NaN   Visited
# 915         131           116      NaN  Searched
# 916         130           115      NaN   Visited
#
#                                             categories  dislikes  likes  \
# 762                                                 []       NaN    NaN
# 763                                                 []       NaN    NaN
# 764                                                 []       NaN    NaN
# 765                                                 []       NaN    NaN
# ...

# %%
# df['query'].dropna(inplace=True)
# searches = df_jan['query'].tolist()

# %%
# def listToString(s):
#     str1 = ""
#     return(str1.join(s))

# listToString(searches)

# %%
text = df_jan['query'].tolist()
map(word_tokenize, text)
df_jan['query'].apply(word_tokenize)
df_jan['query'].apply(word_tokenize).tolist()
tagged_list = nltk.pos_tag_sents(df_jan['query'].apply(word_tokenize).tolist())
tagged_list
# Out:
# [[('hebrew', 'NN'), ('strong', 'JJ'), ('465', 'CD')],
#  [('prometheus', 'NN')],
#  [('Strong', 'NNP'),
#   ("'s", 'POS'),
#   ('Hebrew', 'NNP'),
#   (':', ':'),
#   ('644', 'CD'),
#   ('.', '.'),
#   ('אָפָה', 'NN'),
#   ('(', '('),
#   ('aphah', 'NN'),
#   (')', ')'),
#   ('--', ':'),
#   ('to', 'TO'),
#   ('bake', 'VB'),
#   ('-', ':'),
#   ('Bible', 'JJ'),
#   ('Hub', 'NN')],
#  [('hebrew', 'NN'), ('strong', 'JJ'), ('644', 'CD')],
#  [('what', 'WP'),
#   ('does', 'VBZ'),
#   ('high', 'JJ'),
#   ('ram', 'NNS'),
#   ('do', 'VBP')],
#  [('champions', 'NNS'),
#   ('league', 'VBP'),
#   ('round', 'NN'),
#   ('of', 'IN'),
#   ('16', 'CD'),
#   ('schedule', 'NN')],
#  [('Red', 'JJ'), ('Bull', 'NNP'), ('Haggard', 'NNP'), ('sold', 'VBD')],
#  [('old', 'JJ'), ('stone', 'NN'), ('tavern', 'NN')],
#  [('https', 'NN'),
#   (':', ':'),
#   ('//www.cbsnews.com/amp/news/pope-francis-pope-apologizes-today-for-swatting-hand-of-woman-before-vatican-mass-new-years-eve-2020-1-1/',
#    'JJ')],
# ...

# %%
noun_list = []
for i in tagged_list:
    temp = [j[0] for j in i if j[1].startswith("NN" or "NNP" or "NNS" or "NNPS")]
    noun_list.append(temp)


noun_list = [[x.lower() for x in sublst] for sublst in noun_list]

print(noun_list)
# Out:
# [['hebrew'], ['prometheus'], ['strong', 'hebrew', 'אָפָה', 'aphah', 'hub'], ['hebrew'], ['ram'], ['champions', 'round', 'schedule'], ['bull', 'haggard'], ['stone', 'tavern'], ['https'], ['pope'], ['https'], ['https'], ['university', 'rochester', 'gym'], ['https'], ['exodus'], ['exodus'], ['https'], ['university', 'rochester', 'gym'], ['seneca', 'zoo', 'hours'], ['seneca', 'zoo', 'hours'], ['https'], ['university', 'rochester', 'gym'], ['lonzo', 'ball', 'stats'], ['dollop', 'gourmet'], ['dollop', 'icing'], ['diollap'], ['camp', 'counselor', 'net', 'worth'], ['nets'], ['pavlok', 'bracelet'], ['hebrew'], ['hebrew'], ['disbursement'], ['ice'], ['disbursement'], ['reviews'], ['tekdry', 'shark', 'tank', 'current', 'gazette', 'review'], ['https', '//www.amazon.com/dp/b07ctylbpx'], ['solemates', 'protectors', 'worth'], ['solemates', 'worth'], ['https'], ['tft', 'season', 'patch'], ['solemates', 'protectors', 'worth'], ['strong', 'greek', 'ἀποτολμάω', 'apotolmaó'], ['strong', 'hebrew', 'אָפַק
# ...

# %%
adj_list = []
for i in tagged_list:
    temp = [j[0] for j in i if j[1].startswith("JJ" or "JJR" or "JJS")]
    adj_list.append(temp)
    
adj_list = [[x.lower() for x in sublst] for sublst in adj_list]

print(adj_list)
# Out:
# [['strong'], [], ['bible'], ['strong'], ['high'], [], ['red'], ['old'], ['//www.cbsnews.com/amp/news/pope-francis-pope-apologizes-today-for-swatting-hand-of-woman-before-vatican-mass-new-years-eve-2020-1-1/'], [], ['//www.cnbc.com/amp/2020/01/01/disgruntled-pope-francis-swats-hand-of-woman-tugging-his-arm.html'], ['//www.rochester.edu/athletics/fitness-center/'], [], ['//www.cnbc.com/amp/2020/01/01/disgruntled-pope-francis-swats-hand-of-woman-tugging-his-arm.html'], [], [], ['//www.rochester.edu/athletics/fitness-center/'], [], [], [], ['//www.rochester.edu/athletics/fitness-center/'], [], [], [], [], [], [], [], [], ['strong'], ['strong'], [], [], [], ['tekdry'], [], [], ['net'], ['net'], ['//www.dailyesports.gg/teamfight-tactics-patch-10-1-adds-new-champions-item-changes-more/amp/'], [], ['net'], ['bold'], ['strong', 'bible'], ['strong'], ['sunscreenr', 'net'], ['//2paragraphs.com/2018/06/sunscreenr-what-happened-to-sunscreen-viewer-after-shark-tank-deal/amp/'], [], [], ['strong'],
# ...

# %%
verb_list = []
for i in tagged_list:
    temp = [j[0] for j in i if j[1].startswith("VB" or "VBD" or "VBG" or "VBN" or "VBP" or "VBZ")]
    verb_list.append(temp)

verb_list = [[x.lower() for x in sublst] for sublst in verb_list]

print(verb_list)
# Out:
# [[], [], ['bake'], [], ['does', 'do'], ['league'], ['sold'], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], ['melt'], [], [], ['updates'], [], ['heel'], [], [], [], ['heel'], ['be'], ['hold', 'be'], [], [], [], ['fill'], ['god'], [], [], [], [], ['look'], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], ['hebrew'], [], [], [], [], [], [], [], [], [], ['schwab'], ['schwab'], [], [], ['saw', 'had', 'answered'], ['are'], [], ['is'], [], [], [], ['led'], ['led'], ['led'], [], [], [], [], ['make', 'boiled'], [], ['is'], ['is'], [], ['is'], [], [], [], ['god'], [], ["'s", 'need'], ['are', 'keto'], [], [], [], [], [], [], [], ['usd'], ['yuan'], ['yuan'], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], ['is', 'place', 'use', 'get'], []]

# %%
string = ""
for l in noun_list:
    if len(l) > 1:
        for word in l:
            string = string + " " + word
        tokens = nltk.word_tokenize(string)  
        bigrm = nltk.bigrams(tokens) 
        print(*map('-'.join, bigrm), sep=', ')
    else:
        print(l)
    string = ""
# Out:
# ['hebrew']
# ['prometheus']
# strong-hebrew, hebrew-אָפָה, אָפָה-aphah, aphah-hub
# ['hebrew']
# ['ram']
# champions-round, round-schedule
# bull-haggard
# stone-tavern
# ['https']
# ['pope']
# ['https']
# ['https']
# university-rochester, rochester-gym
# ['https']
# ['exodus']
# ['exodus']
# ['https']
# university-rochester, rochester-gym
# seneca-zoo, zoo-hours
# seneca-zoo, zoo-hours
# ['https']
# university-rochester, rochester-gym
# lonzo-ball, ball-stats
# dollop-gourmet
# dollop-icing
# ['diollap']
# camp-counselor, counselor-net, net-worth
# ['nets']
# pavlok-bracelet
# ['hebrew']
# ['hebrew']
# ['disbursement']
# ['ice']
# ['disbursement']
# ['reviews']
# tekdry-shark, shark-tank, tank-current, current-gazette, gazette-review
# https-//www.amazon.com/dp/b07ctylbpx
# solemates-protectors, protectors-worth
# solemates-worth
# ['https']
# tft-season, season-patch
# solemates-protectors, protectors-worth
# strong-greek, greek-ἀποτολμάω, ἀποτολμάω-apotolmaó
# ...

# %%
string = ""
for l in adj_list:
    if len(l) > 1:
        for word in l:
            string = string + " " + word
        tokens = nltk.word_tokenize(string)  
        bigrm = nltk.bigrams(tokens) 
        print(*map('-'.join, bigrm), sep=', ')
    else:
        print(l)
    string = ""
# Out:
# ['strong']
# []
# ['bible']
# ['strong']
# ['high']
# []
# ['red']
# ['old']
# ['//www.cbsnews.com/amp/news/pope-francis-pope-apologizes-today-for-swatting-hand-of-woman-before-vatican-mass-new-years-eve-2020-1-1/']
# []
# ['//www.cnbc.com/amp/2020/01/01/disgruntled-pope-francis-swats-hand-of-woman-tugging-his-arm.html']
# ['//www.rochester.edu/athletics/fitness-center/']
# []
# ['//www.cnbc.com/amp/2020/01/01/disgruntled-pope-francis-swats-hand-of-woman-tugging-his-arm.html']
# []
# []
# ['//www.rochester.edu/athletics/fitness-center/']
# []
# []
# []
# ['//www.rochester.edu/athletics/fitness-center/']
# []
# []
# []
# []
# []
# []
# []
# []
# ['strong']
# ['strong']
# []
# []
# []
# ['tekdry']
# []
# []
# ['net']
# ['net']
# ['//www.dailyesports.gg/teamfight-tactics-patch-10-1-adds-new-champions-item-changes-more/amp/']
# []
# ['net']
# ['bold']
# strong-bible
# ['strong']
# sunscreenr-net
# ...

# %%
string = ""
for l in verb_list:
    if len(l) > 1:
        for word in l:
            string = string + " " + word
        tokens = nltk.word_tokenize(string)  
        bigrm = nltk.bigrams(tokens) 
        print(*map('-'.join, bigrm), sep=', ')
    else:
        print(l)
    string = ""
# Out:
# []
# []
# ['bake']
# []
# does-do
# ['league']
# ['sold']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['melt']
# []
# []
# ['updates']
# []
# ['heel']
# []
# []
# []
# ['heel']
# ['be']
# hold-be
# []
# []
# []
# ['fill']
# ['god']
# []
# []
# []
# []
# ['look']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['hebrew']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['schwab']
# ['schwab']
# []
# []
# saw-had, had-answered
# ['are']
# []
# ['is']
# []
# []
# []
# ['led']
# ['led']
# ['led']
# []
# []
# []
# []
# make-boiled
# []
# ['is']
# ['is']
# []
# ['is']
# []
# []
# []
# ['god']
# []
# 's-need
# are-keto
# []
# []
# []
# []
# []
# []
# []
# ['usd']
# ['yuan']
# ['yuan']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# is-place, place-use, use-get
# []

# %%
df_feb = df[(df.months == 2) & (df.years == 2020)]

# %%
text = df_feb['query'].tolist()
map(word_tokenize, text)
df_feb['query'].apply(word_tokenize)
df_feb['query'].apply(word_tokenize).tolist()
tagged_list_feb = nltk.pos_tag_sents(df_feb['query'].apply(word_tokenize).tolist())

# %%
noun_list_feb = []
for i in tagged_list_feb:
    temp = [j[0] for j in i if j[1].startswith("NN" or "NNP" or "NNS" or "NNPS")]
    noun_list_feb.append(temp)

noun_list_feb = [[x.lower() for x in sublst] for sublst in noun_list_feb]

print(noun_list_feb)
# Out:
# [['right'], ['right'], ['knocks'], ['ny', 'knicks'], ['ny', 'knicks'], ['ny', 'knicks'], ['wings', 'keto'], ['keto', 'buffalo', 'wings'], ['keto', 'diet', 'try', 'wings', '|', 'buffalo', 'wings', 'rings'], ['bowl'], ['bowl'], ['air', 'clients', 'bowl'], ['air', 'jordan', 'clients'], ['air', 'clients', 'bowl'], ['facilities', 'services', 'service', 'requests'], ['facilities', 'services', 'university', 'rochester'], ['facilities', 'university', 'rochester'], ['iphone'], ['verse', 'jars'], ['job'], ['corinthians', 'business', 'mine'], ['corinthians', 'do', 'angels'], ['verse', 'judging', 'angels'], ['corinthians', 'niv', 'bible'], ['verse', 'souls', 'men'], ['revelation', 'gateway'], ['pharisees', 'jesus', 'messiah'], ['candlesticks'], ['candlesticks', 'existence', 'god'], ['candlesticks', 'creation', 'verse'], ['candlesticks', 'creation'], ['ron', 'goldman'], ['games', 'today'], ['games', 'today'], ['games', 'today'], ['games', 'today'], ['hebrew'], ['evan', 'turner'], ['pareto', 'opti
# ...

# %%
adj_list_feb = []
for i in tagged_list_feb:
    temp = [j[0] for j in i if j[1].startswith("JJ" or "JJR" or "JJS")]
    adj_list_feb.append(temp)
    
adj_list_feb = [[x.lower() for x in sublst] for sublst in adj_list_feb]

print(adj_list_feb)
# Out:
# [['better'], ['better'], [], [], [], [], ['eat'], ['best'], [], ['super'], ['super'], ['super'], [], ['super'], [], [], [], [], ['bible', 'broken'], ['bible'], [], [], ['bible'], ['6:3-4'], ['bible'], ['bible'], ['false'], ['bible'], [], ['bible'], [], [], ['nba'], ['nba'], ['nba'], ['nba'], ['strong'], [], [], [], [], [], [], [], [], [], ['amy'], ['many', 'fourth'], ['much'], ['many'], ['much'], [], ['//www.cbssports.com/nba/news/andre-iguodala-recalls-his-favorite-memory-playing-with-stephen-curry-warriors-during-return-trip-to-bay-area/amp/'], [], [], [], [], ['plastic'], [], [], ['other'], [], [], [], [], ['beam'], [], ['beam'], [], [], [], [], [], [], [], ['rid'], ['rid'], [], [], [], ['festival'], ['//www.sas.rochester.edu/dan/news-events/inspiredance/'], ['rid'], ['strong'], [], [], [], [], [], [], [], [], ['festival'], ['//www.sas.rochester.edu/dan/news-events/inspiredance/'], [], [], [], ["o'brien"], [], ['memorial'], ['memorial'], [], ['strong'], [], [], [], [], ['soft']]

# %%
verb_list_feb = []
for i in tagged_list_feb:
    temp = [j[0] for j in i if j[1].startswith("VB" or "VBD" or "VBG" or "VBN" or "VBP" or "VBZ")]
    verb_list_feb.append(temp)

verb_list_feb = [[x.lower() for x in sublst] for sublst in verb_list_feb]

print(verb_list_feb)
# Out:
# [['is', 'sleep', 'left'], ['is', 'sleep', 'left'], [], [], [], [], ['i'], ['wickedstuffed'], ['eat'], ['is'], ['is'], ['jordan'], [], ['jordan'], [], [], [], ['restart'], [], ['says', 'judge'], ['is', 'judge'], ['know', 'judge'], [], ['do', 'know', 'judge'], ['sell'], [], ['say', 'was'], [], ['prove'], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], ['is'], ['is'], ['are'], ['does'], ['oz'], [], [], [], [], ['remove'], ['get'], [], [], ['are'], [], [], [], [], ['is'], ['turn'], ['is'], ['turn', 'is'], [], ['upside', 'be'], ['have', 'turned'], ['i'], [], [], ['get'], ['get'], [], [], [], [], [], ['get'], [], [], [], [], [], [], [], [], ['makes', 'sleepy'], [], [], ['league'], ['league'], [], [], [], [], [], [], [], [], [], [], [], ['is']]

# %%
string = ""
for l in noun_list_feb:
    if len(l) > 1:
        for word in l:
            string = string + " " + word
        tokens = nltk.word_tokenize(string)  
        bigrm = nltk.bigrams(tokens) 
        print(*map('-'.join, bigrm), sep=', ')
    else:
        print(l)
    string = ""
# Out:
# ['right']
# ['right']
# ['knocks']
# ny-knicks
# ny-knicks
# ny-knicks
# wings-keto
# keto-buffalo, buffalo-wings
# keto-diet, diet-try, try-wings, wings-|, |-buffalo, buffalo-wings, wings-rings
# ['bowl']
# ['bowl']
# air-clients, clients-bowl
# air-jordan, jordan-clients
# air-clients, clients-bowl
# facilities-services, services-service, service-requests
# facilities-services, services-university, university-rochester
# facilities-university, university-rochester
# ['iphone']
# verse-jars
# ['job']
# corinthians-business, business-mine
# corinthians-do, do-angels
# verse-judging, judging-angels
# corinthians-niv, niv-bible
# verse-souls, souls-men
# revelation-gateway
# pharisees-jesus, jesus-messiah
# ['candlesticks']
# candlesticks-existence, existence-god
# candlesticks-creation, creation-verse
# candlesticks-creation
# ron-goldman
# games-today
# games-today
# games-today
# games-today
# ['hebrew']
# evan-turner
# pareto-optimum
# ['flyspeedcity']
# ['flyspeedcity']
# ...

# %%
string = ""
for l in verb_list_feb:
    if len(l) > 1:
        for word in l:
            string = string + " " + word
        tokens = nltk.word_tokenize(string)  
        bigrm = nltk.bigrams(tokens) 
        print(*map('-'.join, bigrm), sep=', ')
    else:
        print(l)
    string = ""
# Out:
# is-sleep, sleep-left
# is-sleep, sleep-left
# []
# []
# []
# []
# ['i']
# ['wickedstuffed']
# ['eat']
# ['is']
# ['is']
# ['jordan']
# []
# ['jordan']
# []
# []
# []
# ['restart']
# []
# says-judge
# is-judge
# know-judge
# []
# do-know, know-judge
# ['sell']
# []
# say-was
# []
# ['prove']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['is']
# ['is']
# ['are']
# ['does']
# ['oz']
# []
# []
# []
# []
# ['remove']
# ['get']
# []
# []
# ['are']
# []
# []
# []
# []
# ['is']
# ['turn']
# ['is']
# turn-is
# []
# upside-be
# have-turned
# ['i']
# []
# []
# ['get']
# ['get']
# []
# []
# []
# []
# []
# ['get']
# []
# []
# []
# []
# []
# []
# []
# []
# makes-sleepy
# []
# []
# ['league']
# ['league']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['is']

# %%
string = ""
for l in adj_list_feb:
    if len(l) > 1:
        for word in l:
            string = string + " " + word
        tokens = nltk.word_tokenize(string)  
        bigrm = nltk.bigrams(tokens) 
        print(*map('-'.join, bigrm), sep=', ')
    else:
        print(l)
    string = ""
# Out:
# ['better']
# ['better']
# []
# []
# []
# []
# ['eat']
# ['best']
# []
# ['super']
# ['super']
# ['super']
# []
# ['super']
# []
# []
# []
# []
# bible-broken
# ['bible']
# []
# []
# ['bible']
# ['6:3-4']
# ['bible']
# ['bible']
# ['false']
# ['bible']
# []
# ['bible']
# []
# []
# ['nba']
# ['nba']
# ['nba']
# ['nba']
# ['strong']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['amy']
# many-fourth
# ['much']
# ['many']
# ['much']
# []
# ['//www.cbssports.com/nba/news/andre-iguodala-recalls-his-favorite-memory-playing-with-stephen-curry-warriors-during-return-trip-to-bay-area/amp/']
# []
# []
# []
# []
# ['plastic']
# []
# []
# ['other']
# []
# []
# []
# []
# ['beam']
# []
# ['beam']
# []
# []
# []
# []
# []
# []
# []
# ['rid']
# ['rid']
# []
# []
# []
# ['festival']
# ['//www.sas.rochester.edu/dan/news-events/inspiredance/']
# ['rid']
# ['strong']
# []
# []
# []
# []
# []
# []
# []
# []
# ['festival']
# ['//www.sas.rochester.edu/dan/news-events/inspiredance/']
# []
# []
# []
# ...
