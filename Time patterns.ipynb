# %%
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
files = glob.glob('data-to-use/*.csv')

# %%
df_feb = df_march = df_jan = df_2019 = df_jan_march = pd.DataFrame(columns=pd.read_csv(files[0]).columns)
for f in files:
    df = pd.read_csv(f)
    df_feb = df_feb.append(df[(df.years == 2020) & (df.months == 2)], ignore_index=True)
    df_march = df_march.append(df[(df.years == 2020) & (df.months == 3)], ignore_index=True)
    df_jan = df_jan.append(df[(df.years == 2020) & (df.months == 1)], ignore_index=True)
    df_2019 = df_jan_march.append(df[(df.years == 2019)], ignore_index=True)
    df_jan_march = df_feb.append(df[(df.years == 2020) & (df.months < 4)], ignore_index=True)

# %% [markdown]
# ### Query Counts

# %%
df_2019.weekdays.value_counts().reset_index(name='queries per weekday').plot(y='queries per weekday')
plt.xlabel('Day of Week')
plt.ylabel('Query Count')
plt.title('Queries per Weekday in 2019')
# Out:
# Text(0.5, 1.0, 'Queries per Weekday in 2019')

# %%
df_jan_march.weekdays.value_counts().reset_index(name='queries per weekday').plot(y='queries per weekday')
plt.xlabel('Day of Week')
plt.ylabel('Query Count')
plt.title('Queries per Weekday January-March 2020')
# Out:
# Text(0.5, 1.0, 'Queries per Weekday January-March 2020')

# %%
df_march.weekdays.value_counts().reset_index(name='queries per weekday').plot(y='queries per weekday')
plt.xlabel('Day of Week')
plt.ylabel('Query Count')
plt.title('Queries per Weekday March 2020')
# Out:
# Text(0.5, 1.0, 'Queries per Weekday March 2020')

# %%
df_feb.weekdays.value_counts().reset_index(name='queries per weekday').plot(y='queries per weekday')
plt.xlabel('Day of Week')
plt.ylabel('Query Count')
plt.title('Queries per Weekday February 2020')
# Out:
# Text(0.5, 1.0, 'Queries per Weekday February 2020')

# %%
df_jan.weekdays.value_counts().reset_index(name='queries per weekday').plot(y='queries per weekday')
plt.xlabel('Day of Week')
plt.ylabel('Query Count')
plt.title('Queries per Weekday January 2020')
# Out:
# Text(0.5, 1.0, 'Queries per Weekday January 2020')

# %%
df_2019.days.value_counts().reset_index(name='queries per day').plot(y='queries per day', xlim=(0,29))
plt.xlabel('Day of the Month')
plt.ylabel('Query Count')
plt.title('Queries per Day of the Month in 2019')
# Out:
# Text(0.5, 1.0, 'Queries per Day of the Month in 2019')

# %%
df_jan.days.value_counts().reset_index(name='queries per day').plot(y='queries per day', xlim=(0,29))
plt.xlabel('Day of the Month')
plt.ylabel('Query Count')
plt.title('Queries per Days in January 2020')
# Out:
# Text(0.5, 1.0, 'Queries per Days in January 2020')

# %%
df_feb.days.value_counts().reset_index(name='queries per day').plot(y='queries per day', xlim=(0,29))
plt.xlabel('Day of the Month')
plt.ylabel('Query Count')
plt.title('Queries per Days in February 2020')
# Out:
# Text(0.5, 1.0, 'Queries per Days in February 2020')

# %%
df_march.days.value_counts().reset_index(name='queries per day').plot(y='queries per day', xlim=(0,29))
plt.xlabel('Day of the Month')
plt.ylabel('Query Count')
plt.title('Queries per Days in March 2020')
# Out:
# Text(0.5, 1.0, 'Queries per Days in March 2020')

# %%
df_jan_march.days.value_counts().reset_index(name='queries per day').plot(y='queries per day', xlim=(0,29))
plt.xlabel('Day of the Month')
plt.ylabel('Query Count')
plt.title('Queries per Days in January-March 2020')
# Out:
# Text(0.5, 1.0, 'Queries per Days in January-March 2020')

# %%
df_2019.hours.value_counts().reset_index(name='queries per hour').plot(y='queries per hour')
plt.xlabel('Hours of the Day')
plt.ylabel('Query Count')
plt.title('Queries per Hour in 2019')
# Out:
# Text(0.5, 1.0, 'Queries per Hour in 2019')

# %%
df_jan.hours.value_counts().reset_index(name='queries per hour').plot(y='queries per hour')
plt.xlabel('Hours of the Day')
plt.ylabel('Query Count')
plt.title('Queries per Hour in January 2020')
# Out:
# Text(0.5, 1.0, 'Queries per Hour in January 2020')

# %%
df_feb.hours.value_counts().reset_index(name='queries per hour').plot(y='queries per hour')
plt.xlabel('Hours of the Day')
plt.ylabel('Query Count')
plt.title('Queries per Hour in February 2020')
# Out:
# Text(0.5, 1.0, 'Queries per Hour in February 2020')

# %%
df_march.hours.value_counts().reset_index(name='queries per hour').plot(y='queries per hour')
plt.xlabel('Hours of the Day')
plt.ylabel('Query Count')
plt.title('Queries per Hour in March 2020')
# Out:
# Text(0.5, 1.0, 'Queries per Hour in March 2020')

# %%
df_jan_march.hours.value_counts().reset_index(name='queries per hour').plot(y='queries per hour')
plt.xlabel('Hours of the Day')
plt.ylabel('Query Count')
plt.title('Queries per Hour January-March 2020')
# Out:
# Text(0.5, 1.0, 'Queries per Hour January-March 2020')

# %%
df_2019.dropna(subset=['durations'])
df_jan.dropna(subset=['durations'])
df_feb.dropna(subset=['durations'])
df_march.dropna(subset=['durations'])
df_jan_march.dropna(subset=['durations'])
# Out:
#       Unnamed: 0 Unnamed: 0.1   ratings   action                categories  \
# 0            900          900  4.903648  Watched  ['Science & Technology']
# 2            898          898  4.944050  Watched                ['Sports']
# 39           897          897  4.817697  Watched                 ['Music']
# 49           893          893  4.976938  Watched                 ['Music']
# 50           892          892  4.977205  Watched                 ['Music']
# ...          ...          ...       ...      ...                       ...
# 62164          5            5  4.724138  Watched        ['People & Blogs']
# 62165          4            4  4.829787  Watched        ['People & Blogs']
# 62167          2            2  4.860627  Watched        ['People & Blogs']
# 62168          1            1  4.930693  Watched        ['People & Blogs']
# 62169          0            0  4.848101  Watched        ['People & Blogs']
#
# ...

# %% [markdown]
# ## Durations

# %%
df_2019.groupby('days').durations.mean().reset_index(name='duration per day').plot(y='duration per day', xlim=(0,29))
plt.xlabel('Days of the Month')
plt.ylabel('Duration (in seconds)')
plt.title('Average Duration of Videos per Day in 2019')
# Out:
# Text(0.5, 1.0, 'Average Duration of Videos per Day in 2019')

# %%
df_jan.groupby('days').durations.mean().reset_index(name='duration per day').plot(y='duration per day', xlim=(0,29))
plt.xlabel('Days of the Month')
plt.ylabel('Duration (in seconds)')
plt.title('Average Duration of Videos per Day in January 2020')
# Out:
# Text(0.5, 1.0, 'Average Duration of Videos per Day in January 2020')

# %%
df_feb.groupby('days').durations.mean().reset_index(name='duration per day').plot(y='duration per day', xlim=(0,29))
plt.xlabel('Days of the Month')
plt.ylabel('Duration (in seconds)')
plt.title('Average Duration of Videos per Day in February 2020')
# Out:
# Text(0.5, 1.0, 'Average Duration of Videos per Day in February 2020')

# %%
df_march.groupby('days').durations.mean().reset_index(name='duration per day').plot(y='duration per day', xlim=(0,29))
plt.xlabel('Days of the Month')
plt.ylabel('Duration (in seconds)')
plt.title('Average Duration of Videos per Day in March 2020')
# Out:
# Text(0.5, 1.0, 'Average Duration of Videos per Day in March 2020')

# %%
df_2019.groupby('hours').durations.mean().reset_index(name='duration per hour').plot(y='duration per hour')
plt.xlabel('Hours of the Day')
plt.ylabel('Duration (in seconds)')
plt.title('Average Duration of Videos per Hour in 2019')
# Out:
# Text(0.5, 1.0, 'Average Duration of Videos per Hour in 2019')

# %%
df_jan.groupby('hours').durations.mean().reset_index(name='duration per hour').plot(y='duration per hour')
plt.xlabel('Hours of the Day')
plt.ylabel('Duration (in seconds)')
plt.title('Average Duration of Videos per Hour in January 2020')
# Out:
# Text(0.5, 1.0, 'Duration of Videos per Hour in January 2020')

# %%
df_feb.groupby('hours').durations.mean().reset_index(name='duration per hour').plot(y='duration per hour')
plt.xlabel('Hours of the Day')
plt.ylabel('Duration (in seconds)')
plt.title('Average Duration of Videos per Hour in February 2020')
# Out:
# Text(0.5, 1.0, 'Duration of Videos per Hour in February 2020')

# %%
df_march.groupby('hours').durations.mean().reset_index(name='duration per hour').plot(y='duration per hour')
plt.xlabel('Hours of the Day')
plt.ylabel('Duration (in seconds)')
plt.title('Average Duration of Videos per Hour in March 2020')
# Out:
# Text(0.5, 1.0, 'Duration of Videos per Hour in March 2020')

# %%
df_2019.groupby('weekdays').durations.mean().reset_index(name='duration per weekday').plot(y='duration per weekday')
plt.xlabel('Days of the Week')
plt.ylabel('Duration (in seconds)')
plt.title('Average Duration of Videos per Weekday in 2019')
# Out:
# Text(0.5, 1.0, 'Duration of Videos per Weekday in 2019')

# %%
df_jan.groupby('weekdays').durations.mean().reset_index(name='duration per weekday').plot(y='duration per weekday')
plt.xlabel('Days of the Week')
plt.ylabel('Duration (in seconds)')
plt.title('Average Duration of Videos per Weekday in January 2020')
# Out:
# Text(0.5, 1.0, 'Duration of Videos per Weekday in January 2020')

# %%
df_feb.groupby('weekdays').durations.mean().reset_index(name='duration per weekday').plot(y='duration per weekday')
plt.xlabel('Days of the Week')
plt.ylabel('Duration (in seconds)')
plt.title('Average Duration of Videos per Weekday in February 2020')
# Out:
# Text(0.5, 1.0, 'Duration of Videos per Weekday in February 2020')

# %%
df_march.groupby('weekdays').durations.mean().reset_index(name='duration per weekday').plot(y='duration per weekday')
plt.xlabel('Days of the Week')
plt.ylabel('Duration (in seconds)')
plt.title('Average Duration of Videos per Weekday in March 2020')
# Out:
# Text(0.5, 1.0, 'Duration of Videos per Weekday in March 2020')

# %%
df_jan_march.groupby('weekdays').durations.mean().reset_index(name='duration per weekday').plot(y='duration per weekday')
plt.xlabel('Days of the Week')
plt.ylabel('Duration (in seconds)')
plt.title('Average Duration of Videos per Weekday January-March 2020')
# Out:
# Text(0.5, 1.0, 'Average Duration of Videos per Weekday January-March 2020')

# %% [markdown]
# ### Duration Sum

# %%
df_2019.groupby('days').durations.sum().reset_index(name='duration per day').plot(y='duration per day', xlim=(0,29))
plt.xlabel('Days of the Month')
plt.ylabel('Duration (in seconds)')
plt.title('Total Duration of Videos per Day in 2019')

df_jan.groupby('days').durations.sum().reset_index(name='duration per day').plot(y='duration per day', xlim=(0,29))
plt.xlabel('Days of the Month')
plt.ylabel('Duration (in seconds)')
plt.title('Total Duration of Videos per Day in January 2020')

df_feb.groupby('days').durations.sum().reset_index(name='duration per day').plot(y='duration per day', xlim=(0,29))
plt.xlabel('Days of the Month')
plt.ylabel('Duration (in seconds)')
plt.title('Total Duration of Videos per Day in February 2020')

df_march.groupby('days').durations.sum().reset_index(name='duration per day').plot(y='duration per day', xlim=(0,29))
plt.xlabel('Days of the Month')
plt.ylabel('Duration (in seconds)')
plt.title('Total Duration of Videos per Day in March 2020')

df_2019.groupby('hours').durations.sum().reset_index(name='duration per hour').plot(y='duration per hour')
plt.xlabel('Hours of the Day')
plt.ylabel('Duration (in seconds)')
plt.title('Total Duration of Videos per Hour in 2019')

df_jan.groupby('hours').durations.sum().reset_index(name='duration per hour').plot(y='duration per hour')
plt.xlabel('Hours of the Day')
plt.ylabel('Duration (in seconds)')
plt.title('Total Duration of Videos per Hour in January 2020')


df_feb.groupby('hours').durations.sum().reset_index(name='duration per hour').plot(y='duration per hour')
plt.xlabel('Hours of the Day')
plt.ylabel('Duration (in seconds)')
plt.title('Total Duration of Videos per Hour in February 2020')


df_march.groupby('hours').durations.sum().reset_index(name='duration per hour').plot(y='duration per hour')
plt.xlabel('Hours of the Day')
plt.ylabel('Duration (in seconds)')
plt.title('Total Duration of Videos per Hour in March 2020')

df_2019.groupby('weekdays').durations.sum().reset_index(name='duration per weekday').plot(y='duration per weekday')
plt.xlabel('Days of the Week')
plt.ylabel('Duration (in seconds)')
plt.title('Total Duration of Videos per Weekday in 2019')

df_jan.groupby('weekdays').durations.sum().reset_index(name='duration per weekday').plot(y='duration per weekday')
plt.xlabel('Days of the Week')
plt.ylabel('Duration (in seconds)')
plt.title('Total Duration of Videos per Weekday in January 2020')

df_feb.groupby('weekdays').durations.sum().reset_index(name='duration per weekday').plot(y='duration per weekday')
plt.xlabel('Days of the Week')
plt.ylabel('Duration (in seconds)')
plt.title('Total Duration of Videos per Weekday in February 2020')

df_march.groupby('weekdays').durations.sum().reset_index(name='duration per weekday').plot(y='duration per weekday')
plt.xlabel('Days of the Week')
plt.ylabel('Duration (in seconds)')
plt.title('Total Duration of Videos per Weekday in March 2020')

df_jan_march.groupby('weekdays').durations.sum().reset_index(name='duration per weekday').plot(y='duration per weekday')
plt.xlabel('Days of the Week')
plt.ylabel('Duration (in seconds)')
plt.title('Total Duration of Videos per Weekday January-March 2020')
# Out:
# Text(0.5, 1.0, 'Total Duration of Videos per Weekday January-March 2020')
