# %%
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
files = glob.glob('data-to-use/*.csv')

# %%
df_feb = df_march = df_jan = df_april = df_may =  pd.DataFrame(columns= pd.read_csv(files[0]).columns)
for f in files:
    df = pd.read_csv(f)
    df_jan = df_jan.append(df[(df.years == 2020) & (df.months == 1)],ignore_index= True)
    df_feb = df_feb.append(df[(df.years == 2020) & (df.months == 2)],ignore_index= True)
    df_march = df_march.append(df[(df.years == 2020) & (df.months == 3)],ignore_index= True)
    df_april = df_april.append(df[(df.years == 2020) & (df.months == 4)],ignore_index= True)
    df_may = df_may.append(df[(df.years == 2020) & (df.months == 5)],ignore_index= True)
df_may
# Out:
#       Unnamed: 0 Unnamed: 0.1  ratings    action  \
# 0            128          128      NaN  Searched
# 1            127          127      NaN  Searched
# 2            126          126      NaN   Visited
# 3            125          125      NaN  Searched
# 4            124          124      NaN  Searched
# ...          ...          ...      ...       ...
# 33360        347            4      NaN  Searched
# 33361        346            3      NaN   Visited
# 33362        345            2      NaN   Visited
# 33363        343            0      NaN   Visited
# 33364        344            1      NaN  Searched
#
#                                               categories  dislikes  likes  \
# 0                                                     []       NaN    NaN
# 1                                                     []       NaN    NaN
# 2                                                     []       NaN    NaN
# 3                                                     []       NaN    NaN
# 4                                                     []       NaN    NaN
# ...                                                  ...       ...    ...
# 33360                                                 []       NaN    NaN
# 33361  [['/News', 0.6100000143051147], ['/Arts & Ente...       NaN    NaN
# 33362               [['/Reference', 0.5699999928474426]]       NaN    NaN
# 33363  [['/Jobs & Education/Education', 0.99000000953...       NaN    NaN
# 33364  [['/Jobs & Education/Education', 0.99000000953...       NaN    NaN
#
#        durations  view_cnts years months days hours minutes weekdays link  \
# 0            NaN        NaN  2020      5    2    22      36        5  NaN
# 1            NaN        NaN  2020      5    2    22      57        5  NaN
# 2            NaN        NaN  2020      5    2    23       4        5  NaN
# 3            NaN        NaN  2020      5    3     0       3        6  NaN
# 4            NaN        NaN  2020      5    3     0       3        6  NaN
# ...          ...        ...   ...    ...  ...   ...     ...      ...  ...
# 33360        NaN        NaN  2020      5   28    19       3        3  NaN
# 33361        NaN        NaN  2020      5   28    19       3        3  NaN
# 33362        NaN        NaN  2020      5   28    19       3        3  NaN
# 33363        NaN        NaN  2020      5   29    10      54        4  NaN
# 33364        NaN        NaN  2020      5   29    10      54        4  NaN
#
#       titles  source                                              query  \
# 0        NaN  search                                   butterfly effect
# 1        NaN  search                                            mustang
# 2        NaN  search  Electric Ford Mustang With 536 HP Coming To Go...
# 3        NaN  search                                        the genesee
# 4        NaN  search                                 the genesee lyrics
# ...      ...     ...                                                ...
# 33360    NaN  search                                   elizabeth may ny
# 33361    NaN  search  Wedding: Richard A. Duvall and Elizabeth M. Ma...
# 33362    NaN  search      Contributions to the tribute of Elizabeth May
# 33363    NaN  search            Anki - powerful, intelligent flashcards
# 33364    NaN  search                                       anki for mac
#
#                   datetime
# 0      2020-05-02 22:36:00
# 1      2020-05-02 22:57:00
# 2      2020-05-02 23:04:00
# 3      2020-05-03 00:03:00
# 4      2020-05-03 00:03:00
# ...                    ...
# 33360  2020-05-28 19:03:00
# 33361  2020-05-28 19:03:00
# 33362  2020-05-28 19:03:00
# 33363  2020-05-29 10:54:00
# 33364  2020-05-29 10:54:00
#
# [33365 rows x 20 columns]

# %%
df.groupby([df['datetime'].dt.strftime('%W')])['quantity'].sum()
